# %% [markdown]
# <a href="https://colab.research.google.com/github/Kanaagalakshmi/Kanaagalakshmisenthil/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
# !pip3 install cvlib
import cvlib as cv
from cvlib.object_detection import draw_bbox
im = cv2.imread('5cars.jpg')
bbox, label, conf = cv.detect_common_objects(im)
output_image = draw_bbox(im, bbox, label, conf)
plt.imshow(output_image)
plt.show()


import cv2
import matplotlib.pyplot as plt
# !pip3 install cvlib
import cvlib as cv
from cvlib.object_detection import draw_bbox
im = cv2.imread('2trains.jpg')
bbox, label, conf = cv.detect_common_objects(im)
output_image = draw_bbox(im, bbox, label, conf)
plt.imshow(output_image)
plt.show()

import cv2
import matplotlib.pyplot as plt
# !pip3 install cvlib
import cvlib as cv
from cvlib.object_detection import draw_bbox
im = cv2.imread('dbm.jpg')
bbox, label, conf = cv.detect_common_objects(im)
output_image = draw_bbox(im, bbox, label, conf)
plt.imshow(output_image)
plt.show()
